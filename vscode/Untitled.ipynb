# %%
import analysis

# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/yuki/Desktop/sushi_proj/pretest_aozora_dinner.csv")

# %%
l = list(df["dinner_review"])
len(l)
# Out:
# 77

# %%
score, review,

# %%
for review in df["dinner_review"]:
    b = analyzer.feature_analysis(review, "/Users/yuki/tabelog_evolution/sample.json")
    print(b)
# Out:
# [['赤酢', 0, ['強い', 0], ['あっさり', 0], ['すっぱい', 0]], ['握り', 2, ['大きい', 0], ['小さい', 0], ['創作', 0]], ['シャリ', 0, ['大きい', 0], ['小さい', 0], ['パラパラ', 0], ['塩気', 0], ['甘い', 0], ['熟成', 0]]]
# [['赤酢', 0, ['強い', 0], ['あっさり', 0], ['すっぱい', 0]], ['握り', 3, ['大きい', 0], ['小さい', 0], ['創作', 0]], ['シャリ', 1, ['大きい', 0], ['小さい', 0], ['パラパラ', 0], ['塩気', 1], ['甘い', 0], ['熟成', 0]]]
# [['赤酢', 0, ['強い', 0], ['あっさり', 0], ['すっぱい', 0]], ['握り', 1, ['大きい', 0], ['小さい', 0], ['創作', 0]], ['シャリ', 11, ['大きい', 1], ['小さい', 1], ['パラパラ', 0], ['塩気', 0], ['甘い', 0], ['熟成', 0]]]
# [['赤酢', 0, ['強い', 0], ['あっさり', 0], ['すっぱい', 0]], ['握り', 15, ['大きい', 0], ['小さい', 0], ['創作', 0]], ['シャリ', 0, ['大きい', 0], ['小さい', 0], ['パラパラ', 0], ['塩気', 0], ['甘い', 0], ['熟成', 0]]]
# [['赤酢', 0, ['強い', 0], ['あっさり', 0], ['すっぱい', 0]], ['握り', 6, ['大きい', 0], ['小さい', 0], ['創作', 0]], ['シャリ', 1, ['大きい', 0], ['小さい', 0], ['パラパラ', 0], ['塩気', 1], ['甘い', 1], ['熟成', 0]]]
# ...

# %%
analyzer = analysis.Analyzer()

# %%
analyzer.tokenize("今日はさいとうに行ってきました。おいしかったです。")
# Out:
# ['今日', 'さ', 'いとう', '行く', 'くる', 'ます', 'た', 'おいしい', 'た', 'です']

# %%
analyzer.feature_analysis("赤酢強い。", "/Users/yuki/tabelog_evolution/sample.json")
# Out:
# [['赤酢', 0, ['強い', 0], ['あっさり', 0], ['すっぱい', 0]],
#  ['握り', 0, ['大きい', 0], ['小さい', 0], ['創作', 0]],
#  ['シャリ',
#   0,
#   ['大きい', 0],
#   ['小さい', 0],
#   ['パラパラ', 0],
#   ['塩気', 0],
#   ['甘い', 0],
#   ['熟成', 0]]]

# %%
for t in dic:
    dic[t]
