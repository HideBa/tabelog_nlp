# %%
import pandas as pd
import MeCab
from collections import Counter, defaultdict

# %%
tagger = MeCab.Tagger("-Ochasen -d /usr/local/lib/mecab/dic/mecab-ipadic-neologd -u /Users/yuki/foo/bar/user_dic2.dic")
tagger.parse("")
# Out:
# 'EOS\n'

# %%
stop_words = ["♦","▪","⚪","・","◾",]

# %%
store_file = ["../pretest_kiyoda_dinner.csv",
              "../pretest_aozora_dinner.csv",
             "../pretest_mitani_lunch.csv",
             "../pretest_mitani_dinner.csv"]

# %%
lunch_file = ["../pretest_sushitsuu_lunch.csv",
              "../pretest_sushiichi_lunch.csv",
              "../pretest_sawada_lunch.csv",
              "../pretest_matsukan_lunch.csv",
              "../pretest_kiyoda_lunch.csv",
              "../pretest_imamura_lunch.csv",
              "../pretest_hatsune_lunch.csv",
              "../pretest_mitani_lunch.csv"
              ]
dinner_file = ["../pretest_sushitsuu_dinner.csv",
              "../pretest_sushiichi_dinner.csv",
              "../pretest_sawada_dinner.csv",
              "../pretest_matsukan_dinner.csv",
              "../pretest_imamura_dinner.csv",
              "../pretest_hatsune_dinner.csv",
                "../pretest_aozora_dinner.csv",
               "../pretest_mitani_dinner.csv"
              ]

# %%
akazu = ["赤酢"]
nigiri = ["握り","にぎり","ニギリ"]
shari = ["シャリ","コメ","米","ライス","こめ","しゃり"]
maguro = ["まぐろ","マグロ","鮪","赤身","トロ","とろ"]
wine = ["ワイン","","",]

# %%
features = [akazu, nigiri, shari, maguro, wine]

# %%
def tokenize_ja(text):
    node = tagger.parseToNode(str(text)) #分かち書きしたのが入っている。イテレータ
    while node:
        surface = node.surface.lower() #surfaceは単語の見た目　例：トろ
        feature = node.feature.split(",")
        hinshi = feature[0]
        genkei = feature[6]
        if surface not in stop_words and surface != "" and hinshi in ["形容詞", "動詞", "副詞", "助動詞", "接続詞", "連体詞", "感動詞", "接頭詞"]:
            yield genkei
        elif surface not in stop_words and surface != "" and hinshi == "名詞":
            yield surface
        node = node.next

# %%
def tokenize(content):
    return [token for token in tokenize_ja(content)]

# %%
all_review_word_lunch = defaultdict(int)
all_review_word_dinner  =defaultdict(int)
num_word_lunch = 0
num_word_dinner = 0
for file in lunch_file:
    df=pd.read_csv(file)
    for review in df["lunch_review"]:
        list=tokenize(review)
        for l in list:
            all_review_word_lunch[l] += 1 #その単語の登場回数を1加える
            num_word_lunch += 1
for file in dinner_file:
    df=pd.read_csv(file)
    for review in df["dinner_review"]:
        list=tokenize(review)
        for l in list:
            all_review_word_dinner[l] += 1 #その単語の登場回数を1加える
            num_word_dinner += 1

# %%
num_word_lunch
# Out:
# 125497

# %%
counter_lunch = Counter(all_review_word_lunch).most_common()

# %%
counter_lunch
# Out:
# [('た', 5182),
#  ('だ', 3540),
#  ('ます', 2913),
#  ('する', 2908),
#  ('です', 2729),
#  ('ない', 1668),
#  ('いる', 1563),
#  ('お', 1436),
#  ('ある', 1196),
#  ('の', 1149),
#  ('れる', 926),
#  ('店', 743),
#  ('握り', 694),
#  ('鮨', 678),
#  ('さん', 637),
#  ('なる', 630),
#  ('こと', 624),
#  ('美味しい', 583),
#  ('ん', 549),
#  ('食べる', 530),
#  ('思う', 506),
#  ('この', 473),
#  ('シャリ', 459),
#  ('さ', 450),
#  ('もの', 446),
#  ('よう', 432),
#  ('ネタ', 423),
#  ('良い', 397),
#  ('たい', 383),
#  ('う', 376),
#  ('予約', 373),
#  ('これ', 368),
#  ('くる', 332),
#  ('方', 318),
#  ('そう', 314),
#  ('寿司', 313),
#  ('鮪', 303),
#  ('その', 302),
#  ('中', 300),
#  ('熟成', 284),
#  ('せる', 283),
#  ('０', 283),
#  ('味', 282),
#  ('１', 281),
#  ('ぬ', 281),
#  ('大将', 277),
#  ('られる', 258),
#  ('感じる', 255),
#  ('ランチ', 253),
#  ('炙る', 251),
#  ('私', 247),
#  ('また', 240),
#  ('しまう', 237),
#  ('握る', 236),
#  ('穴子', 235),
#  ('くれる', 234),
#  ('行く', 232),
#  ('２', 226),
#  ('酢', 223),
#  ('カウンター', 223),
#  ('言う', 218),
#  ('前', 210),
#  ('こちら', 209),
#  ('日', 207),
#  ('頂く', 207),
#  ('ご', 207),
#  ('雲丹', 206),
#  ('赤身', 206),
#  ('いただく', 205),
#  ('中トロ', 200),
#  ('訪問', 197),
#  ('一', 197),
#  ('口', 196),
#  ('入る', 196),
#  ('できる', 192),
#  ('つまむ', 192),
#  ('貫', 190),
#  ('ここ', 190),
#  ('それ', 190),
#  ('塩', 189),
#  ('出る', 187),
#  ('香り', 186),
#  ('マグロ', 184),
#  ('素晴らしい', 183),
#  ('そして', 183),
#  ('三谷', 182),
#  ('席', 180),
#  ('脂', 179),
#  ('料理', 179),
#  ('入れる', 177),
#  ('いい', 176),
#  ('てる', 174),
#  ('みる', 172),
#  ('目', 171),
#  ('伺う', 168),
#  ('感じ', 166),
#  ('出す', 165),
#  ('感', 163),
#  ('おる', 163),
#  ('大トロ', 162),
#  ('少し', 162),
#  ('今回', 161),
#  ('旨味', 161),
#  ('お酒', 160),
#  ('漬け', 158),
#  ('コース', 157),
#  ('いう', 156),
#  ('とても', 156),
#  ('時間', 155),
#  ('夜', 154),
#  ('時', 153),
#  ('的', 151),
#  ('高い', 150),
#  ('事', 149),
#  ('甘い', 146),
#  ('人', 146),
#  ('最高', 143),
#  ('赤', 142),
#  ('仕事', 142),
#  ('かなり', 140),
#  ('田', 140),
#  ('産', 139),
#  ('３', 137),
#  ('銀座', 137),
#  ('昼', 135),
#  ('魚', 135),
#  ('気', 134),
#  ('今', 131),
#  ('旨い', 131),
#  ('ウニ', 130),
#  ('身', 130),
#  ('よい', 130),
#  ('しっかり', 128),
#  ('主人', 127),
#  ('好き', 126),
#  ('円', 126),
#  ('車海老', 125),
#  ('いく', 125),
#  ('強い', 124),
#  ('ところ', 123),
#  ('使う', 122),
#  ('好み', 120),
#  ('煮る', 120),
#  ('後', 118),
#  ('雰囲気', 118),
#  ('来る', 117),
#  ('最後', 115),
#  ('さわ', 115),
#  ('初めて', 114),
#  ('お昼', 114),
#  ('上', 114),
#  ('見る', 114),
#  ('トロ', 113),
#  ('昆布', 113),
#  ('何', 112),
#  ('玉子', 112),
#  ('鮨屋', 112),
#  ('多い', 110),
#  ('寿司屋', 110),
#  ('すぎる', 110),
#  ('飲む', 106),
#  ('すし', 106),
#  ('にぎる', 106),
#  ('1', 105),
#  ('本当に', 105),
#  ('旨み', 105),
#  ('食感', 104),
#  ('店内', 104),
#  ('肝', 103),
#  ('他', 102),
#  ('大きい', 101),
#  ('印象', 101),
#  ('無い', 101),
#  ('手', 100),
#  ('濃厚', 100),
#  ('おいしい', 99),
#  ('ちょっと', 98),
#  ('ろ', 98),
#  ('５', 97),
#  ('包丁', 97),
#  ('日本酒', 97),
#  ('鰹', 97),
#  ('ワイン', 96),
#  ('楽しむ', 95),
#  ('いくら', 95),
#  ('うに', 94),
#  ('もう', 93),
#  ('鮑', 93),
#  ('赤貝', 93),
#  ('素材', 92),
#  ('2', 91),
#  ('5', 91),
#  ('8', 90),
#  ('鯖', 90),
#  ('聞く', 90),
#  ('出来る', 89),
#  ('最初', 89),
#  ('以上', 89),
#  ('満足', 89),
#  ('一番', 89),
#  ('違う', 88),
#  ('甘み', 88),
#  ('なかなか', 88),
#  ('自分', 88),
#  ('品', 86),
#  ('軍艦', 86),
#  ('鯛', 86),
#  ('海苔', 84),
#  ('笑', 84),
#  ('でも', 84),
#  ('合わせる', 83),
#  ('大', 82),
#  ('巻き', 82),
#  ('3', 81),
#  ('大間', 80),
#  ('特に', 80),
#  ('酒', 80),
#  ('二', 80),
#  ('写真', 80),
#  ('ため', 80),
#  ('再訪', 80),
#  ('追加', 80),
#  ('よく', 80),
#  ('様', 79),
#  ('値段', 78),
#  ('楽しい', 78),
#  ('残る', 78),
#  ('椀', 78),
#  ('り', 78),
#  ('白子', 78),
#  ('変わる', 77),
#  ('客', 77),
#  ('巻く', 77),
#  ('全て', 77),
#  ('お願い', 77),
#  ('しれる', 76),
#  ('もちろん', 76),
#  ('烏賊', 76),
#  ('くださる', 75),
#  ('き', 75),
#  ('種', 75),
#  ('柔らかい', 74),
#  ('鯵', 74),
#  ('め', 74),
#  ('分', 74),
#  ('デザート', 74),
#  ('どれ', 74),
#  ('ふる', 74),
#  ('玉', 73),
#  ('年', 73),
#  ('おまかせ', 73),
#  ('蟹', 73),
#  ('やる', 72),
#  ('店主', 72),
#  ('物', 72),
#  ('バランス', 72),
#  ('コハダ', 72),
#  ('貝', 71),
#  ('江戸前', 70),
#  ('数', 70),
#  ('女将', 70),
#  ('６', 69),
#  ('丁寧', 69),
#  ('海老', 68),
#  ('味わい', 68),
#  ('澤田', 68),
#  ('そんな', 67),
#  ('イカ', 67),
#  ('美味い', 67),
#  ('通', 67),
#  ('白', 67),
#  ('今日', 66),
#  ('非常', 66),
#  ('スタート', 66),
#  ('度', 66),
#  ('食', 66),
#  ('11', 66),
#  ('感動', 66),
#  ('温度', 66),
#  ('楽しめる', 65),
#  ('合う', 65),
#  ('いつも', 65),
#  ('本日', 64),
#  ('東京', 64),
#  ('ただ', 64),
#  ('乗せる', 64),
#  ('蒸す', 63),
#  ('生', 62),
#  ('もらう', 62),
#  ('酸味', 62),
#  ('金目鯛', 61),
#  ('ござる', 61),
#  ('しかし', 61),
#  ('考える', 61),
#  ('ひる', 61),
#  ('先', 60),
#  ('とろける', 60),
#  ('同じ', 60),
#  ('わかる', 60),
#  ('焼き', 60),
#  ('種類', 60),
#  ('肉', 60),
#  ('親方', 60),
#  ('酢飯', 60),
#  ('提供', 59),
#  ('やはり', 59),
#  ('万', 59),
#  ('出汁', 59),
#  ('ビール', 59),
#  ('僕', 58),
#  ('電話', 58),
#  ('づける', 57),
#  ('らしい', 57),
#  ('墨烏賊', 57),
#  ('昆布締め', 56),
#  ('まだ', 56),
#  ('常連', 56),
#  ('三', 56),
#  ('味噌汁', 55),
#  ('４', 55),
#  ('邪魔', 55),
#  ('嬉しい', 55),
#  ('舌', 55),
#  ('美しい', 55),
#  ('前回', 55),
#  ('贅沢', 55),
#  ('ご飯', 55),
#  ('巻物', 54),
#  ('うまい', 54),
#  ('ねっとり', 54),
#  ('こはだ', 54),
#  ('任せる', 54),
#  ('過ぎる', 53),
#  ('ぶり', 53),
#  ('たっぷり', 53),
#  ('高級', 53),
#  ('お茶', 53),
#  ('イクラ', 53),
#  ('凄い', 53),
#  ('取れる', 53),
#  ('みたい', 52),
#  ('12', 52),
#  ('あと', 52),
#  ('つく', 52),
#  ('わけ', 52),
#  ('白海老', 52),
#  ('す', 52),
#  ('待つ', 52),
#  ('すごい', 51),
#  ('絶妙', 51),
#  ('接客', 51),
#  ('楽しみ', 51),
#  ('すべて', 51),
#  ('あ', 51),
#  ('蛤', 50),
#  ('内容', 50),
#  ('レベル', 50),
#  ('皮', 50),
#  ('間', 50),
#  ('見える', 50),
#  ('鮃', 50),
#  ('まずは', 50),
#  ('こんな', 49),
#  ('絶品', 49),
#  ('まぐろ', 49),
#  ('あまり', 49),
#  ('次', 49),
#  ('ばらちらし', 49),
#  ('やや', 49),
#  ('人気', 49),
#  ('食事', 49),
#  ('取る', 49),
#  ('具合', 48),
#  ('切る', 48),
#  ('風味', 48),
#  ('焼く', 48),
#  ('普通', 48),
#  ('甘味', 48),
#  ('とる', 48),
#  ('量', 48),
#  ('分かる', 48),
#  ('持つ', 48),
#  ('驚く', 48),
#  ('醤油', 48),
#  ('話', 48),
#  ('干瓢', 48),
#  ('名', 47),
#  ('のどぐろ', 47),
#  ('行う', 47),
#  ('場所', 47),
#  ('通り', 47),
#  ('８', 47),
#  ('職人', 47),
#  ('藁', 47),
#  ('巻', 47),
#  ('べし', 46),
#  ('とき', 46),
#  ('かける', 46),
#  ('000', 46),
#  ('全く', 46),
#  ('次回', 46),
#  ('ら', 46),
#  ('鰤', 46),
#  ('ヶ月', 45),
#  ('濃い', 45),
#  ('色々', 45),
#  ('回', 45),
#  ('評価', 45),
#  ('寝かせる', 45),
#  ('る', 45),
#  ('舎利', 45),
#  ('上品', 44),
#  ('小肌', 44),
#  ('味わう', 44),
#  ('美味', 44),
#  ('ツメ', 44),
#  ('初', 44),
#  ('相性', 44),
#  ('一人', 44),
#  ('貫目', 44),
#  ('十', 44),
#  ('説明', 43),
#  ('そこ', 43),
#  ('幸せ', 43),
#  ('カツオ', 43),
#  ('初音', 43),
#  ('系', 42),
#  ('つける', 42),
#  ('注文', 42),
#  ('鮓', 42),
#  ('細かい', 42),
#  ('ちゃう', 42),
#  ('個人的', 42),
#  ('いただける', 42),
#  ('心', 42),
#  ('すぐ', 42),
#  ('一貫', 42),
#  ('引き出す', 42),
#  ('悪い', 42),
#  ('天然', 42),
#  ('グラス', 42),
#  ('それぞれ', 41),
#  ('スープ', 41),
#  ('のる', 41),
#  ('スタイル', 41),
#  ('お客様', 41),
#  ('通う', 41),
#  ('平目', 41),
#  ('一品', 41),
#  ('本', 41),
#  ('まあ', 41),
#  ('氏', 41),
#  ('⚫', 41),
#  ('6', 40),
#  ('でる', 40),
#  ('噛む', 40),
#  ('厚', 40),
#  ('気持ち', 40),
#  ('価格', 40),
#  ('アイス', 40),
#  ('確か', 40),
#  ('期待', 40),
#  ('山葵', 40),
#  ('空間', 40),
#  ('状態', 39),
#  ('残念', 39),
#  ('茶碗蒸し', 39),
#  ('シャンパン', 39),
#  ('７', 39),
#  ('広がる', 39),
#  ('カラスミ', 39),
#  ('キャビア', 39),
#  ('ホタテ', 38),
#  ('魚の', 38),
#  ('溶ける', 38),
#  ('抜群', 38),
#  ('香ばしい', 38),
#  ('海胆', 38),
#  ('以前', 38),
#  ('始まる', 38),
#  ('終わる', 38),
#  ('欲しい', 38),
#  ('一緒', 38),
#  ('小柱', 38),
#  ('最近', 37),
#  ('結構', 37),
#  ('まず', 37),
#  ('以下', 37),
#  ('お客さん', 37),
#  ('続く', 37),
#  ('やすい', 37),
#  ('置く', 37),
#  ('綺麗', 37),
#  ('作る', 37),
#  ('くい', 37),
#  ('堪能', 37),
#  ('つ', 37),
#  ('供', 37),
#  ('大好き', 37),
#  ('印籠', 37),
#  ('鱧', 37),
#  ('超', 36),
#  ('満席', 36),
#  ('瞬間', 36),
#  ('ごちそうさま', 36),
#  ('4', 36),
#  ('梅', 36),
#  ('いま', 36),
#  ('安い', 36),
#  ('優しい', 36),
#  ('忘れる', 36),
#  ('定食', 36),
#  ('言葉', 36),
#  ('こだわり', 36),
#  ('知る', 36),
#  ('白身', 36),
#  ('蛸', 36),
#  ('おつまみ', 36),
#  ('ミシュラン', 36),
#  ('◽', 36),
#  ('女性', 35),
#  ('六本木', 35),
#  ('やっぱり', 35),
#  ('さらに', 35),
#  ('カワハギ', 35),
#  ('乗る', 35),
#  ('溢れる', 35),
#  ('紹介', 35),
#  ('アワビ', 35),
#  ('させる', 35),
#  ('続ける', 35),
#  ('鰆', 35),
#  ('小鰭', 35),
#  ('毛蟹', 35),
#  ('個室', 34),
#  ('落ち着く', 34),
#  ('時期', 34),
#  ('思える', 34),
#  ('少ない', 34),
#  ('入店', 34),
#  ('なんと', 34),
#  ('点', 34),
#  ('サービス', 34),
#  ('味噌', 34),
#  ('会計', 34),
#  ('素敵', 34),
#  ('質', 34),
#  ('面白い', 34),
#  ('居心地', 34),
#  ('10', 34),
#  ('卵', 34),
#  ('若い', 33),
#  ('アオリイカ', 33),
#  ('軽い', 33),
#  ('近く', 33),
#  ('以外', 33),
#  ('バラちらし', 33),
#  ('いろいろ', 33),
#  ('食材', 33),
#  ('程度', 33),
#  ('米', 33),
#  ('近い', 32),
#  ('とっても', 32),
#  ('エビ', 32),
#  ('たくさん', 32),
#  ('7', 32),
#  ('ヒラメ', 32),
#  ('屋', 32),
#  ('緊張', 32),
#  ('ヅケ', 32),
#  ('しかも', 32),
#  ('さすが', 32),
#  ('書く', 32),
#  ('ガリ', 32),
#  ('こういう', 32),
#  ('どう', 32),
#  ('ま', 32),
#  ('レビュー', 32),
#  ('松茸', 32),
#  ('頭', 31),
#  ('これだけ', 31),
#  ('見た目', 31),
#  ('今年', 31),
#  ('季節', 31),
#  ('さて', 31),
#  ('新鮮', 31),
#  ('アジ', 31),
#  ('ー', 31),
#  ('本鮪', 31),
#  ('伝わる', 31),
#  ('厚い', 31),
#  ('夏', 31),
#  ('あぶる', 31),
#  ('わさび', 31),
#  ('腹', 31),
#  ('かんぴょう', 31),
#  ('皿', 30),
#  ('効く', 30),
#  ('大変', 30),
#  ('有名', 30),
#  ('黒', 30),
#  ('姿', 30),
#  ('当然', 30),
#  ('下', 30),
#  ('見事', 30),
#  ('小さい', 30),
#  ('その後', 30),
#  ('もっと', 30),
#  ('とにかく', 30),
#  ('いや', 30),
#  ('比べる', 30),
#  ('手渡し', 29),
#  ('技術', 29),
#  ('自体', 29),
#  ('メニュー', 29),
#  ('分かれる', 29),
#  ('加減', 29),
#  ('撮る', 29),
#  ('出て', 29),
#  ('形', 29),
#  ('かかる', 29),
#  ('意味', 29),
#  ('歩く', 29),
#  ('受ける', 29),
#  ('アナゴ', 29),
#  ('刺身', 29),
#  ('色', 29),
#  ('始める', 29),
#  ('こ', 29),
#  ('や', 29),
#  ('小', 29),
#  ('ひと', 29),
#  ('一つ', 29),
#  ('炊く', 29),
#  ('唐墨', 29),
#  ('記憶', 29),
#  ('キロ', 29),
#  ('奥様', 29),
#  ('特徴', 28),
#  ('おく', 28),
#  ('じ', 28),
#  ('締め', 28),
#  ('さっぱり', 28),
#  ('9', 28),
#  ('９', 28),
#  ('奥', 28),
#  ('いっぱい', 28),
#  ('たまご', 28),
#  ('間違い', 28),
#  ('訪れる', 28),
#  ('シマアジ', 28),
#  ('まさに', 28),
#  ('部分', 28),
#  ('新', 28),
#  ('会話', 28),
#  ('使用', 28),
#  ('友人', 28),
#  ('良さ', 28),
#  ('び', 28),
#  ('ひらめ', 28),
#  ('ソース', 28),
#  ('約', 28),
#  ('星', 28),
#  ('鰻', 28),
#  ('マリアージュ', 27),
#  ('強める', 27),
#  ('半', 27),
#  ('臭み', 27),
#  ('玉子焼き', 27),
#  ('薄い', 27),
#  ('ご馳走様', 27),
#  ('http://', 27),
#  ('等', 27),
#  ('早い', 27),
#  ('焼き魚', 27),
#  ('ちょうど', 27),
#  ('なり', 27),
#  ('経験', 27),
#  ('粒', 26),
#  ('変化', 26),
#  ('食べログ', 26),
#  ('西麻布', 26),
#  ('六', 26),
#  ('どの', 26),
#  ('暖簾', 26),
#  ('せい', 26),
#  ('もう少し', 26),
#  ('笑顔', 26),
#  ('まるで', 26),
#  ('オーダー', 26),
#  ('加える', 26),
#  ('酒肴', 26),
#  ('付ける', 26),
#  ('字', 26),
#  ('いける', 26),
#  ('⭐', 26),
#  ('余韻', 25),
#  ('大きな', 25),
#  ('さば', 25),
#  ('カステラ', 25),
#  ('弟子', 25),
#  ('どちら', 25),
#  ('2015', 25),
#  ('相変わらず', 25),
#  ('長い', 25),
#  ('ズワイガニ', 25),
#  ('深い', 25),
#  ('あの', 25),
#  ('上がる', 25),
#  ('タネ', 25),
#  ('和える', 25),
#  ('世界', 25),
#  ('づ', 25),
#  ('型', 25),
#  ('では', 25),
#  ('挟む', 25),
#  ('十分', 25),
#  ('小ぶり', 25),
#  ('営業', 25),
#  ('アイスクリーム', 25),
#  ('燻す', 25),
#  ('個性', 24),
#  ('主張', 24),
#  ('なん', 24),
#  ('ビル', 24),
#  ('感覚', 24),
#  ('上質', 24),
#  ('いらっしゃる', 24),
#  ('驚き', 24),
#  ('正直', 24),
#  ('納得', 24),
#  ('なお', 24),
#  ('抜く', 24),
#  ('ほう', 24),
#  ('味わえる', 24),
#  ('当日', 24),
#  ('そういう', 24),
#  ('歯応え', 24),
#  ('是非', 24),
#  ('程よい', 24),
#  ('技', 24),
#  ('制', 24),
#  ('為', 24),
#  ('云', 24),
#  ('頂ける', 24),
#  ('旬', 24),
#  ('サイズ', 24),
#  ('全体', 24),
#  ('相当', 24),
#  ('お客', 24),
#  ('マイクロトマト', 24),
#  ('蝦蛄', 24),
#  ('必要', 23),
#  ('ノドグロ', 23),
#  ('すみいか', 23),
#  ('空気', 23),
#  ('実は', 23),
#  ('12時', 23),
#  ('もん', 23),
#  ('きちんと', 23),
#  ('しっとり', 23),
#  ('飲み物', 23),
#  ('ありがとう', 23),
#  ('帆立', 23),
#  ('見せる', 23),
#  ('うち', 23),
#  ('ごと', 23),
#  ('たち', 23),
#  ('魅力', 23),
#  ('利用', 23),
#  ('機会', 23),
#  ('独特', 23),
#  ('実に', 23),
#  ('日本', 23),
#  ('合', 23),
#  ('登場', 23),
#  ('ステーキ', 23),
#  ('詰め', 23),
#  ('カマ', 23),
#  ('きよ', 23),
#  ('タイプ', 22),
#  ('弾力', 22),
#  ('太刀魚', 22),
#  ('下さる', 22),
#  ('あなご', 22),
#  ('30', 22),
#  ('そのまま', 22),
#  ('ずわい蟹', 22),
#  ('言える', 22),
#  ('頃', 22),
#  ('研究', 22),
#  ('外', 22),
#  ('空く', 22),
#  ('2人', 22),
#  ('ずっと', 22),
#  ('流れ', 22),
#  ('お話', 22),
#  ('盛る', 22),
#  ('全部', 22),
#  ('縞鯵', 22),
#  ('ゆっくり', 22),
#  ('水分', 22),
#  ('覚える', 22),
#  ('ちゃんと', 22),
#  ('白魚', 22),
#  ('スミイカ', 22),
#  ('むら', 22),
#  ('不思議', 21),
#  ('はず', 21),
#  ('焼き物', 21),
#  ('たり', 21),
#  ('選択', 21),
#  ('小さな', 21),
#  ('名店', 21),
#  ('コク', 21),
#  ('連れる', 21),
#  ('した', 21),
#  ('温かい', 21),
#  ('進化', 21),
#  ('進む', 21),
#  ('ちなみに', 21),
#  ('く', 21),
#  ('繊維', 21),
#  ('湯', 21),
#  ('一度', 21),
#  ('ひとつ', 21),
#  ('清潔感', 21),
#  ('こんなに', 21),
#  ('こだわる', 21),
#  ('用', 21),
#  ('ぢ', 21),
#  ('こう', 21),
#  ('帰る', 21),
#  ('新子', 21),
#  ('上げる', 21),
#  ('茹でる', 21),
#  ('きつい', 21),
#  ('立派', 21),
#  ('紫', 21),
#  ('好む', 21),
#  ('唐津', 21),
#  ('漬ける', 20),
#  ('汁', 20),
#  ('ゃり', 20),
#  ('繊細', 20),
#  ('そのもの', 20),
#  ('これから', 20),
#  ('行ける', 20),
#  ('実際', 20),
#  ('ほぼ', 20),
#  ('難しい', 20),
#  ('伺い', 20),
#  ('勿論', 20),
#  ('代わり', 20),
#  ('地下', 20),
#  ('変える', 20),
#  ('違い', 20),
#  ('タイミング', 20),
#  ('噂', 20),
#  ('通常', 20),
#  ('なか', 20),
#  ('話す', 20),
#  ('至福', 20),
#  ('階', 20),
#  ('造り', 20),
#  ('爽やか', 20),
#  ('あり', 20),
#  ('あるじ', 20),
#  ('燒', 20),
#  ('異なる', 20),
#  ('冷蔵庫', 20),
#  ('，', 20),
#  ('1年', 20),
#  ('最', 20),
#  ('昼間', 20),
#  ('印象的', 20),
#  ('からすみ', 20),
#  ('インターホン', 20),
#  ('子持ち', 20),
#  ('細魚', 20),
#  ('牡蠣', 20),
#  ('l', 20),
#  ('来年', 20),
#  ('ハマグリ', 19),
#  ('極上', 19),
#  ('丼', 19),
#  ('側', 19),
#  ('1人', 19),
#  ('消える', 19),
#  ('珍しい', 19),
#  ('用意', 19),
#  ('仕込み', 19),
#  ('姿勢', 19),
#  ('しまあじ', 19),
#  ('平日', 19),
#  ('部', 19),
#  ('付く', 19),
#  ('決して', 19),
#  ('施す', 19),
#  ('同時に', 19),
#  ('鮮度', 19),
#  ('後半', 19),
#  ('逆', 19),
#  ('びっくり', 19),
#  ('一体感', 19),
#  ('者', 19),
#  ('ーー', 19),
#  ('押す', 19),
#  ('通す', 19),
#  ('隣', 19),
#  ('喉', 19),
#  ('モノ', 19),
#  ('カット', 19),
#  ('小鉢', 19),
#  ('某', 19),
#  ('案内', 19),
#  ('いたす', 19),
#  ('選ぶ', 19),
#  ('気さく', 19),
#  ('cp', 19),
#  ('白木', 19),
#  ('場', 19),
#  ('鱚', 19),
#  ('千葉', 19),
#  ('待ち', 19),
#  ('過ごせる', 18),
#  ('１つ', 18),
#  ('ほたて', 18),
#  ('硬い', 18),
#  ('タレ', 18),
#  ('口コミ', 18),
#  ('全', 18),
#  ('カニ', 18),
#  ('開店', 18),
#  ('ほとんど', 18),
#  ('対応', 18),
#  ('器', 18),
#  ('つけ', 18),
#  ('ブログ', 18),
#  ('今度', 18),
#  ('お勧め', 18),
#  ('お腹', 18),
#  ('週間', 18),
#  ('到着', 18),
#  ('更に', 18),
#  ('ブレンド', 18),
#  ('完璧', 18),
#  ('付け', 18),
#  ('常に', 18),
#  ('所', 18),
#  ('組み合わせ', 18),
#  ('毎回', 18),
#  ('新しい', 18),
#  ('頼む', 18),
#  ('完全', 18),
#  ('固め', 18),
#  ('座る', 18),
#  ('ゆく', 18),
#  ('まま', 18),
#  ('にくい', 18),
#  ('い', 18),
#  ('連続', 18),
#  ('杯', 18),
#  ('生きる', 18),
#  ('特大', 18),
#  ('築地', 18),
#  ('海', 18),
#  ('音', 18),
#  ('イメージ', 18),
#  ('丁度', 18),
#  ('のせる', 18),
#  ('絶対', 18),
#  ('鰯', 18),
#  ('かんぴょう巻き', 18),
#  ('鳥貝', 18),
#  ('蛇腹', 18),
#  ('シャコ', 18),
#  ('あわび', 18),
#  ('風', 17),
#  ('一つ一つ', 17),
#  ('赤酢', 17),
#  ('0', 17),
#  ('別', 17),
#  ('あら', 17),
#  ('開ける', 17),
#  ('開く', 17),
#  ('本来', 17),
#  ('あたり', 17),
#  ('感謝', 17),
#  ('久しぶり', 17),
#  ('気に入る', 17),
#  ('静か', 17),
#  ('くぐる', 17),
#  ('挨拶', 17),
#  ('何度', 17),
#  ('究極', 17),
#  ('含める', 17),
#  ('数々', 17),
#  ('必ず', 17),
#  ('負ける', 17),
#  ...]

# %%
df = pd.read_csv(store_file[3])

# %%
#以下黒越さんの要望資料作成用

# %%
dic = defaultdict(int)
word_times = 0 #全単語数
for review in df["dinner_review"]:
    sentences = review.split("。")
    for s in sentences:
        token_list = tokenize(s) #各レビューを形態素解析
        for token in token_list:
            word_times += 1
            if (token in akazu) or (token in nigiri) or \
        (token in shari) or (token in maguro) or (token in wine):
                dic[token] += 1

# %%
word_times
# Out:
# 24953

# %%
dic
# Out:
# defaultdict(int,
#             {'トロ': 18,
#              '握り': 108,
#              '赤身': 21,
#              'ワイン': 73,
#              '鮪': 43,
#              'マグロ': 38,
#              'まぐろ': 13,
#              'シャリ': 18,
#              '米': 2})

# %%
"赤身" in dic
# Out:
# True

# %%
l = []
for feature in features:
    for f in feature:
        if f in dic:
            ll = [feature[0], f, str(dic[f]) + "回", str(int(10000*dic[f]/word_times)/100)+"%", 
                  str(int(10000*all_review_word_dinner[f]/num_word_dinner)/100)+"%",
                  str(int(100*(dic[f]/word_times)/(all_review_word_dinner[f]/num_word_dinner))/100)+"倍"]
            l.append(ll)

# %%
l
# Out:
# [['握り', '握り', '108回', '0.43%', '0.57%', '0.74倍'],
#  ['シャリ', 'シャリ', '18回', '0.07%', '0.37%', '0.19倍'],
#  ['シャリ', '米', '2回', '0.0%', '0.02%', '0.26倍'],
#  ['まぐろ', 'まぐろ', '13回', '0.05%', '0.05%', '1.03倍'],
#  ['まぐろ', 'マグロ', '38回', '0.15%', '0.17%', '0.87倍'],
#  ['まぐろ', '鮪', '43回', '0.17%', '0.25%', '0.66倍'],
#  ['まぐろ', '赤身', '21回', '0.08%', '0.21%', '0.39倍'],
#  ['まぐろ', 'トロ', '18回', '0.07%', '0.08%', '0.82倍'],
#  ['ワイン', 'ワイン', '73回', '0.29%', '0.06%', '4.84倍']]

# %%
columns = ["軸となる単語","軸のグループ単語","登場回数","全単語に対する登場頻度%（登場回数/全単語数）","他の店での登場頻度%","他の店に比べて何倍登場しやすいか"]

# %%
df1 = pd.DataFrame(l, columns=columns)

# %%
df1
# Out:
#   軸となる単語 軸のグループ単語  登場回数 全単語に対する登場頻度%（登場回数/全単語数） 他の店での登場頻度% 他の店に比べて何倍登場しやすいか
# 0     握り       握り  108回                   0.43%      0.57%            0.74倍
# 1    シャリ      シャリ   18回                   0.07%      0.37%            0.19倍
# 2    シャリ        米    2回                    0.0%      0.02%            0.26倍
# 3    まぐろ      まぐろ   13回                   0.05%      0.05%            1.03倍
# 4    まぐろ      マグロ   38回                   0.15%      0.17%            0.87倍
# 5    まぐろ        鮪   43回                   0.17%      0.25%            0.66倍
# 6    まぐろ       赤身   21回                   0.08%      0.21%            0.39倍
# 7    まぐろ       トロ   18回                   0.07%      0.08%            0.82倍
# 8    ワイン      ワイン   73回                   0.29%      0.06%            4.84倍

# %%
df1.to_csv("mitani_dinner_syousai.csv", index=False, encoding="SHIFT-JIS")

# %%
lll = []
for feature in features:
    n = 0
    s = 0
    m = ""
    for f in feature:
        n += dic[f]
        s += all_review_word_dinner[f]
        m += " " + f + " " + str(dic[f]) + "回" +","
    ll = [feature[0],str(n)+"回", str(int(10000*n/word_times)/100)+"%", str(int(10000*s/num_word_dinner)/100)+"%",
         str(int(100*(n/word_times)/(s/num_word_dinner))/100)+"倍", m]
    lll.append(ll)

# %%
columns2 = ["軸となる単語","登場回数","全単語に対する登場頻度%（登場回数/全単語数）","他の店での登場頻度%","他の店に比べて何倍登場しているか","詳細:軸のグループ単語とその登場回数"]

# %%
df2 = pd.DataFrame(lll, columns=columns2)

# %%
df2
# Out:
#   軸となる単語  登場回数 全単語に対する登場頻度%（登場回数/全単語数） 他の店での登場頻度% 他の店に比べて何倍登場しているか  \
# 0     赤酢    0回                    0.0%       0.0%             0.0倍
# 1     握り  108回                   0.43%      0.57%            0.74倍
# 2    シャリ   20回                   0.08%       0.4%            0.19倍
# 3    まぐろ  133回                   0.53%      0.78%            0.68倍
# 4    ワイン   73回                   0.29%      0.06%            4.84倍
#
#                                  詳細:軸のグループ単語とその登場回数
# 0                                            赤酢 0回,
# 1                          握り 108回, にぎり 0回, ニギリ 0回,
# 2      シャリ 18回, コメ 0回, 米 2回, ライス 0回, こめ 0回, しゃり 0回,
# 3   まぐろ 13回, マグロ 38回, 鮪 43回, 赤身 21回, トロ 18回, とろ 0回,
# 4                                ワイン 73回,  0回,  0回,

# %%
df2.to_csv("mitani_dinner.csv", index=False, encoding="SHIFT-JIS")

# %%
m = ""
m += "赤身"
m
# Out:
# '赤身'

# %%
#以下提案資料作成用 未完成

# %%
df["dinner_review"][0].split("。")
# Out:
# ['銀座でも別格のネームバリューを持つ鮨屋',
#  '食べログでの評価は4.46(2019.09.22)と超高評価店です',
#  '訪問のハードルが高いお店だと思っていたのですが、最近では新規の客にも門戸を開いているようです',
#  '摘み星鰈赤身、トロ、小肌、貝柱若布鮑雲丹トロ(炙り)平貝潮汁(星鰈)握り新子赤身烏賊星鰈鯵トロミル貝小肌車海老雲丹鉄火巻き穴子玉もろきゅう干瓢巻きマスカット酢飯は赤酢を使用しており、しょっぱい鮨です',
#  'ぼやけた味わいにはならないですが、喉が渇くと思います',
#  '酢〆はちゃんと〆てありますが、酸味が尖っているということはありませんでした',
#  '鮪への強いこだわりで有名なだけあって、鮪が美味しい時期とは言い難かったと思うのですが、さすがのクオリティでした',
#  '是非、別の季節にも訪問してみたいと思いました',
#  '雰囲気はサロンのようなものを想像していたのですが、隣客に恵まれたこともあってか、楽しい時間を過ごすことができました',
#  'サービスも良好の一言',
#  '冷酒(黒龍)を少しいただいて、お会計は一人当たり5万円台半ば',
#  '立地や内容を考慮しても支払額は高いと思いますが、予約は取りやすかったです',
#  '']

# %%
#for review in df["dinner_review"]:
    #li = review.split("。")
    #for i in li:
        #l = tokenize(i)
        #if "まぐろ" and "美味しい" in l:
            #print("t")

# %%
#l
